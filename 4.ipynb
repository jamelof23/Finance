# %% [markdown]
# <a href="https://colab.research.google.com/github/jamelof23/Finance/blob/main/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
import os

def get_sp500_symbols():
    symbols = set()

    # Fetch S&P 500 symbols
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_response = requests.get(sp500_url)
    if sp500_response.status_code == 200:
        sp500_tables = pd.read_html(sp500_response.content)
        for table in sp500_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("S&P 500 symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve S&P 500 data.")

    # Fetch Dow Jones symbols
    dow_url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'
    dow_response = requests.get(dow_url)
    if dow_response.status_code == 200:
        dow_tables = pd.read_html(dow_response.content)
        for table in dow_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("Dow Jones symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve Dow Jones data.")

    # Fetch NASDAQ-listed symbols
    nasdaq_url = 'http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqlisted.txt'
    nasdaq_response = requests.get(nasdaq_url)
    if nasdaq_response.status_code == 200:
        nasdaq_data = nasdaq_response.text.splitlines()
        for line in nasdaq_data:
            if line.startswith('Symbol|'):
                continue  # Skip header
            if 'File Creation Time' in line or 'Nasdaq Trader' in line:
                continue  # Skip footer
            parts = line.split('|')
            symbol = parts[0]
            if symbol:
                symbols.add(symbol)
        print("NASDAQ symbols fetched successfully.")
    else:
        print("Failed to retrieve NASDAQ data.")

    return list(symbols)

def get_insider_trades_finnhub(api_key, symbol):
    url = f'https://finnhub.io/api/v1/stock/insider-transactions?symbol={symbol}&token={api_key}'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if 'data' in data and data['data']:
            df = pd.DataFrame(data['data'])
            df['TransactionType'] = df['change'].apply(lambda x: 'Buy' if x > 0 else 'Sell')
            return df
    else:
        print(f"Failed to retrieve data for {symbol}. Status code: {response.status_code}")
    return None

def fetch_all_insider_trades(api_key, symbols, max_workers=5):
    all_trades = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(get_insider_trades_finnhub, api_key, symbol): symbol for symbol in symbols}

        for future in as_completed(futures):
            symbol = futures[future]
            try:
                data = future.result()
                if data is not None:
                    data['Symbol'] = symbol  # Add symbol column to data
                    all_trades.append(data)
            except Exception as e:
                print(f"Error fetching data for {symbol}: {e}")

    return pd.concat(all_trades, ignore_index=True) if all_trades else pd.DataFrame()

# Get your API key from finnhub.io
api_key = 'csea3f1r01qs1ihohl6gcsea3f1r01qs1ihohl70'

# Fetch the list of all symbols
all_symbols = get_sp500_symbols()

# Fetch insider trades concurrently
all_insider_trades_df = fetch_all_insider_trades(api_key, all_symbols[:], max_workers=10)  # Limited to 5 symbols for demonstration

# Save the results to an Excel file in Colab's working directory
file_path = "/content/insider_trades.xlsx"
all_insider_trades_df.to_excel(file_path, index=False)

print(f"Insider trades data saved to {file_path}")

# Provide a download link
from google.colab import files
files.download(file_path)


print(f"Insider trades data saved to {desktop_path}")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Failed to retrieve data for FMST. Status code: 429
# Failed to retrieve data for NAUT. Status code: 429
# Failed to retrieve data for WNW. Status code: 429
# Failed to retrieve data for THCP. Status code: 429
# Failed to retrieve data for IINNW. Status code: 429
# Failed to retrieve data for TBPH. Status code: 429
# Failed to retrieve data for POWW. Status code: 429
# Failed to retrieve data for WHF. Status code: 429
# Failed to retrieve data for NKTX. Status code: 429Failed to retrieve data for PNW. Status code: 429
#
# Failed to retrieve data for ORMP. Status code: 429
# Failed to retrieve data for MRTN. Status code: 429
# Failed to retrieve data for TECX. Status code: 429
# Failed to retrieve data for ATMCU. Status code: 429
# Failed to retrieve data for BDX. Status code: 429
# Failed to retrieve data for TELA. Status code: 429
# Failed to retrieve data for CHCI. Status code: 429
# Failed to retrieve data for WNDY. Status code: 429
# Failed to retrieve data for CORZ. Status code: 429Failed to retrieve data for TNGX. Status code: 429
# Failed to retrieve data for PNFPP. Status code: 429
# Failed to retrieve data for NWL. Status code: 429
# Failed to retrieve data for RAPT. Status code: 429
#
# Failed to retrieve data for AILE. Status code: 429Failed to retrieve data for SABSW. Status code: 429
#
# Failed to retrieve data for HDSN. Status code: 429
# Failed to retrieve data for VIGL. Status code: 429
# Failed to retrieve data for ARBE. Status code: 429
# Failed to retrieve data for DYCQR. Status code: 429
# Failed to retrieve data for CAMP. Status code: 429
# Failed to retrieve data for LTRN. Status code: 429
# Failed to retrieve data for BHFAM. Status code: 429
# Failed to retrieve data for CCGWW. Status code: 429
# Failed to retrieve data for AMCX. Status code: 429
# Failed to retrieve data for GO. Status code: 429
# Failed to retrieve data for APH. Status code: 429
# Failed to retrieve data for INOD. Status code: 429
# Failed to retrieve data for VMBS. Status code: 429
# Failed to retrieve data for PRAX. Status code: 429
# Failed to retrieve data for IIIV. Status code: 429
# Failed to retrieve data for BITF. Status code: 429
# Failed to retrieve data for SPRC. Status code: 429
# Failed to retrieve data for TTSH. Status code: 429
# Failed to retrieve data for XFOR. Status code: 429
# Failed to retrieve data for APCX. Status code: 429
# Failed to retrieve data for AMPH. Status code: 429
# Failed to retrieve data for PEP. Status code: 429
# Insider trades data saved to /content/insider_trades.xlsx
# Insider trades data saved to C:/Users/arbasjax/Desktop/insider_trades.xlsx

# %%
import requests
import pandas as pd
import time

def get_sp500_symbols():
    symbols = set()

    # Fetch S&P 500 symbols
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_response = requests.get(sp500_url)
    if sp500_response.status_code == 200:
        sp500_tables = pd.read_html(sp500_response.content)

        # Loop through tables to find the correct one
        for table in sp500_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("S&P 500 symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve S&P 500 data.")

    # Fetch Dow Jones symbols
    dow_url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'
    dow_response = requests.get(dow_url)
    if dow_response.status_code == 200:
        dow_tables = pd.read_html(dow_response.content)

        # Loop through tables to find the correct one
        for table in dow_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("Dow Jones symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve Dow Jones data.")

    # Fetch NASDAQ-listed symbols
    nasdaq_url = 'http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqlisted.txt'
    nasdaq_response = requests.get(nasdaq_url)
    if nasdaq_response.status_code == 200:
        nasdaq_data = nasdaq_response.text.splitlines()
        for line in nasdaq_data:
            if line.startswith('Symbol|'):
                continue  # Skip header
            if 'File Creation Time' in line or 'Nasdaq Trader' in line:
                continue  # Skip footer
            parts = line.split('|')
            symbol = parts[0]
            if symbol:
                symbols.add(symbol)
        print("NASDAQ symbols fetched successfully.")
    else:
        print("Failed to retrieve NASDAQ data.")

    return list(symbols)

def get_insider_trades_finnhub(api_key, symbol, max_retries=3, delay=5):
    url = f'https://finnhub.io/api/v1/stock/insider-transactions?symbol={symbol}&token={api_key}'
    retries = 0

    while retries < max_retries:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            if 'data' in data and data['data']:
                df = pd.DataFrame(data['data'])
                df['TransactionType'] = df['change'].apply(lambda x: 'Buy' if x > 0 else 'Sell')
                return df
        elif response.status_code == 429:
            print(f"Rate limit exceeded for {symbol}. Retrying in {delay} seconds...")
            time.sleep(delay)
            retries += 1
        else:
            print(f"Failed to retrieve data for {symbol}. Status code: {response.status_code}")
            return None

    print(f"Exceeded max retries for {symbol}. Skipping.")
    return None





# No delay upgrade finhub plan
# def get_insider_trades_finnhub(api_key, symbol):
#     url = f'https://finnhub.io/api/v1/stock/insider-transactions?symbol={symbol}&token={api_key}'
#     response = requests.get(url)

#     if response.status_code == 200:
#         data = response.json()
#         if 'data' in data and data['data']:
#             df = pd.DataFrame(data['data'])
#             buy_transactions = df[df['change'] > 0]
#             sell_transactions = df[df['change'] < 0]
#             return {'Buy': buy_transactions, 'Sell': sell_transactions}
#     else:
#         print(f"Failed to retrieve data for {symbol}. Status code: {response.status_code}")
#     return None

# Get your API key from finnhub.io
api_key = 'csea3f1r01qs1ihohl6gcsea3f1r01qs1ihohl70'

# Fetch the list of all symbols
all_symbols = get_sp500_symbols()

# Dictionary to store insider trades
all_insider_trades = {}

for symbol in all_symbols[:5]:  # Limited to 5 for demonstration
    print(f"Fetching insider transactions for {symbol}...")
    trades = get_insider_trades_finnhub(api_key, symbol)
    if trades:
        all_insider_trades[symbol] = trades
    time.sleep(1)

# Display results
for symbol, trades in all_insider_trades.items():
    print(f"\n{symbol} Insider Buy Transactions:")
    print(trades['Buy'] if not trades['Buy'].empty else "No recent buy transactions.")
    print(f"\n{symbol} Insider Sell Transactions:")
    print(trades['Sell'] if not trades['Sell'].empty else "No recent sell transactions.")
# Out:
# S&P 500 symbols fetched successfully.
# Dow Jones symbols fetched successfully.
# NASDAQ symbols fetched successfully.
# Fetching insider transactions for IGTA...
# Rate limit exceeded for IGTA. Retrying in 5 seconds...
# Rate limit exceeded for IGTA. Retrying in 5 seconds...
# Rate limit exceeded for IGTA. Retrying in 5 seconds...
# Exceeded max retries for IGTA. Skipping.
# Fetching insider transactions for CAH...
# Rate limit exceeded for CAH. Retrying in 5 seconds...
# Rate limit exceeded for CAH. Retrying in 5 seconds...
# Rate limit exceeded for CAH. Retrying in 5 seconds...
# Exceeded max retries for CAH. Skipping.
# Fetching insider transactions for CRGO...
# Rate limit exceeded for CRGO. Retrying in 5 seconds...
# Rate limit exceeded for CRGO. Retrying in 5 seconds...
# Rate limit exceeded for CRGO. Retrying in 5 seconds...
# Exceeded max retries for CRGO. Skipping.
# Fetching insider transactions for DVLU...
# Rate limit exceeded for DVLU. Retrying in 5 seconds...
# Rate limit exceeded for DVLU. Retrying in 5 seconds...
# Rate limit exceeded for DVLU. Retrying in 5 seconds...
# Exceeded max retries for DVLU. Skipping.
# Fetching insider transactions for AENT...
# Rate limit exceeded for AENT. Retrying in 5 seconds...
# Rate limit exceeded for AENT. Retrying in 5 seconds...
# Rate limit exceeded for AENT. Retrying in 5 seconds...
# Exceeded max retries for AENT. Skipping.

# %%
Good code

# %%
import requests
import pandas as pd
import time

def get_sp500_symbols():
    symbols = set()

    # Fetch S&P 500 symbols
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_response = requests.get(sp500_url)
    if sp500_response.status_code == 200:
        sp500_tables = pd.read_html(sp500_response.content)

        # Loop through tables to find the correct one
        for table in sp500_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("S&P 500 symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve S&P 500 data.")

    # Fetch Dow Jones symbols
    dow_url = 'https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average'
    dow_response = requests.get(dow_url)
    if dow_response.status_code == 200:
        dow_tables = pd.read_html(dow_response.content)

        # Loop through tables to find the correct one
        for table in dow_tables:
            if 'Symbol' in table.columns:
                symbols.update(table['Symbol'].tolist())
                print("Dow Jones symbols fetched successfully.")
                break
    else:
        print("Failed to retrieve Dow Jones data.")

    # Fetch NASDAQ-listed symbols
    nasdaq_url = 'http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqlisted.txt'
    nasdaq_response = requests.get(nasdaq_url)
    if nasdaq_response.status_code == 200:
        nasdaq_data = nasdaq_response.text.splitlines()
        for line in nasdaq_data:
            if line.startswith('Symbol|'):
                continue  # Skip header
            if 'File Creation Time' in line or 'Nasdaq Trader' in line:
                continue  # Skip footer
            parts = line.split('|')
            symbol = parts[0]
            if symbol:
                symbols.add(symbol)
        print("NASDAQ symbols fetched successfully.")
    else:
        print("Failed to retrieve NASDAQ data.")

    return list(symbols)





def get_insider_trades_finnhub(api_key, symbol):
    url = f'https://finnhub.io/api/v1/stock/insider-transactions?symbol={symbol}&token={api_key}'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if 'data' in data and data['data']:
            df = pd.DataFrame(data['data'])
            buy_transactions = df[df['change'] > 0]
            sell_transactions = df[df['change'] < 0]
            return {'Buy': buy_transactions, 'Sell': sell_transactions}
    else:
        print(f"Failed to retrieve data for {symbol}. Status code: {response.status_code}")
    return None

# Get your API key from finnhub.io
api_key = 'csea3f1r01qs1ihohl6gcsea3f1r01qs1ihohl70'

# Fetch the list of all symbols
all_symbols = get_sp500_symbols()

# Dictionary to store insider trades
all_insider_trades = {}

for symbol in all_symbols[:5]:  # Limited to 5 for demonstration
    print(f"Fetching insider transactions for {symbol}...")
    trades = get_insider_trades_finnhub(api_key, symbol)
    if trades:
        all_insider_trades[symbol] = trades
    time.sleep(1)

# Display results
for symbol, trades in all_insider_trades.items():
    print(f"\n{symbol} Insider Buy Transactions:")
    print(trades['Buy'] if not trades['Buy'].empty else "No recent buy transactions.")
    print(f"\n{symbol} Insider Sell Transactions:")
    print(trades['Sell'] if not trades['Sell'].empty else "No recent sell transactions.")
# Out:
# S&P 500 symbols fetched successfully.
# Dow Jones symbols fetched successfully.
# NASDAQ symbols fetched successfully.
# Fetching insider transactions for LBTYA...
# Fetching insider transactions for TIGR...
# Fetching insider transactions for BK...
# Fetching insider transactions for MGNI...
# Fetching insider transactions for POWI...
#
# LBTYA Insider Buy Transactions:
#      change currency  filingDate                    id  isDerivative  \
# 4      8831           2024-05-23  0001570585-24-000196          True
# 5      8831           2024-05-23  0001570585-24-000196          True
# 6      3333           2024-05-23  0001570585-24-000196          True
# 7      3333           2024-05-23  0001570585-24-000196          True
# 9      3726           2024-05-23  0001570585-24-000196         False
# ..      ...      ...         ...                   ...           ...
# 204     884           2024-03-04  0001570585-24-000065         False
# 208     746           2024-03-04  0001570585-24-000062         False
# 210     373           2024-03-04  0001570585-24-000062         False
# 214    1046           2024-03-04  0001570585-24-000061         False
# 216     523           2024-03-04  0001570585-24-000061         False
#
#                     name   share source symbol transactionCode  \
# 4            COLE ANDREW    8831    sec  LBTYA               A
# 5            COLE ANDREW    8831    sec  LBTYA               A
# 6            COLE ANDREW    3333    sec  LBTYA               A
# 7            COLE ANDREW    3333    sec  LBTYA               A
# 9            COLE ANDREW   37193    sec  LBTYA               M
# ..                   ...     ...    ...    ...             ...
# 204       Salvato Andrea  120212    sec  LBTYA               M
# 208         HALL BRYAN H  134648    sec  LBTYA               M
# 210         HALL BRYAN H  142287    sec  LBTYA               M
# 214  BRACKEN CHARLES H R    5482    sec  LBTYA               M
# 216  BRACKEN CHARLES H R   48515    sec  LBTYA               M
#
#     transactionDate  transactionPrice
# 4        2024-05-21               0.0
# 5        2024-05-21               0.0
# 6        2024-05-21               0.0
# 7        2024-05-21               0.0
# 9        2024-05-21               0.0
# ..              ...               ...
# 204      2024-03-01               0.0
# 208      2024-03-01               0.0
# 210      2024-03-01               0.0
# 214      2024-03-01               0.0
# 216      2024-03-01               0.0
#
# [126 rows x 12 columns]
#
# LBTYA Insider Sell Transactions:
#      change currency  filingDate                    id  isDerivative  \
# 0    -37600           2024-09-17  0001570585-24-000271         False
# 1    -38000           2024-07-30  0001570585-24-000243         False
# 2     -3726           2024-05-23  0001570585-24-000196          True
# 3     -1863           2024-05-23  0001570585-24-000196          True
# 8      -589           2024-05-23  0001570585-24-000196         False
# ..      ...      ...         ...                   ...           ...
# 215    -246           2024-03-04  0001570585-24-000061         False
# 217  -11226           2024-02-29  0001570585-24-000054         False
# 218  -50000           2024-01-12  0001570585-24-000003         False
# 2     -165           2024-08-23  0000833640-24-000149         False
# 9    -1412           2024-06-18  0000833640-24-000126         False
# 10   -9500           2024-05-28  0000833640-24-000124         False
# 11   -4512           2024-05-24  0000833640-24-000122         False
# ..     ...      ...         ...                   ...           ...
# 85  -14652           2023-12-01  0000833640-23-000203         False
# 86  -47422           2023-12-01  0000833640-23-000202         False
# 87   -6994           2023-11-27  0000833640-23-000199         False
# 88   -3273           2023-11-16  0000833640-23-000197         False
# 89   -5475           2023-11-16  0000833640-23-000196         False
#
#                  name   share source symbol transactionCode transactionDate  \
# 1         Gupta Sunil   51899    sec   POWI               S      2024-08-27
# 2         Bailey Doug   94924    sec   POWI               S      2024-08-21
# 9      Yee Yang Chiah   45436    sec   POWI               S      2024-06-17
# 10  Matthews David MH   53729    sec   POWI               S      2024-05-28
# 11        Gupta Sunil   53861    sec   POWI               S      2024-05-22
# ..                ...     ...    ...    ...             ...             ...
# 85     NAYYAR SANDEEP   74055    sec   POWI               S      2023-11-30
# 86  BALAKRISHNAN BALU  525603    sec   POWI               S      2023-11-29
# 87  Matthews David MH   62200    sec   POWI               S      2023-11-22
# 88        Bailey Doug  100896    sec   POWI               S      2023-11-15
# 89  Matthews David MH   69194    sec   POWI               S      2023-11-14
#
#     transactionPrice
# 1            65.9003
# 2            66.9976
# 9            73.7500
# 10           77.1671
# 11           78.2500
# ..               ...
# 85           76.2236
# 86           77.6022
# 87           77.6924
# 88           78.4272
# 89           76.1388
#
# [67 rows x 12 columns]

# %% [markdown]
# First Version only S&P

# %%
import requests
import pandas as pd
import time

def get_sp500_symbols():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    response = requests.get(url)

    if response.status_code == 200:
        table = pd.read_html(response.content, match='Symbol')[0]
        return table['Symbol'].tolist()
    else:
        print("Failed to retrieve S&P 500 data.")
        return []

def get_insider_trades_finnhub(api_key, symbol):
    url = f'https://finnhub.io/api/v1/stock/insider-transactions?symbol={symbol}&token={api_key}'
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        if 'data' in data and data['data']:
            df = pd.DataFrame(data['data'])
            buy_transactions = df[df['change'] > 0]
            sell_transactions = df[df['change'] < 0]
            return {'Buy': buy_transactions, 'Sell': sell_transactions}
    else:
        print(f"Failed to retrieve data for {symbol}. Status code: {response.status_code}")
    return None

# Get your API key from finnhub.io
api_key = 'csea3f1r01qs1ihohl6gcsea3f1r01qs1ihohl70'

# Fetch the list of S&P 500 symbols
sp500_symbols = get_sp500_symbols()

# Dictionary to store insider trades
all_insider_trades = {}

for symbol in sp500_symbols[:5]:  # Limited to 5 for demonstration
    print(f"Fetching insider transactions for {symbol}...")
    trades = get_insider_trades_finnhub(api_key, symbol)
    if trades:
        all_insider_trades[symbol] = trades
    time.sleep(1)

# Display results
for symbol, trades in all_insider_trades.items():
    print(f"\n{symbol} Insider Buy Transactions:")
    print(trades['Buy'] if not trades['Buy'].empty else "No recent buy transactions.")
    print(f"\n{symbol} Insider Sell Transactions:")
    print(trades['Sell'] if not trades['Sell'].empty else "No recent sell transactions.")
